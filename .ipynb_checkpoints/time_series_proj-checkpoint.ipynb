# %%
import pandas as pd
import os
import requests
import glob

  
path = ("/Users/chris/codeup-data-science/time_series_exercises/fitbit")
  
all_files = glob.glob(path + "/*.csv")

li = []
my_cols=['Foods','Activities','Date','Calories Burned','Steps','Distance','Floors','Minutes Sedentary','Minutes Lightly Active','Minutes Fairly Active','Minutes Very Active','Activity Calories']

for filename in all_files:

    df = pd.read_csv(filename, index_col=None, names=my_cols, engine = 'python')

    li.append(df)

df = pd.concat(li, axis=0, ignore_index=False,)

# %%
df.head(40)
# Out:
#          Foods       Activities    Date Calories Burned   Steps  \
# 0        Foods             None    None            None    None
# 1         Date      Calories In    None            None    None
# 2   2018-09-27                0    None            None    None
# 3   2018-09-28                0    None            None    None
# 4   2018-09-29                0    None            None    None
# 5   2018-09-30                0    None            None    None
# 6   2018-10-01                0    None            None    None
# 7   2018-10-02                0    None            None    None
# 8   2018-10-03                0    None            None    None
# 9   2018-10-04                0    None            None    None
# 10  2018-10-05                0    None            None    None
# 11  2018-10-06                0    None            None    None
# 12  2018-10-07                0    None            None    None
# 13  2018-10-08                0    None            None    None
# ...

# %%
df.to_csv('fitbit.csv')

# %%
df
# Out:
#           Foods   Activities     Date Calories Burned Steps Distance Floors  \
# 0         Foods         None     None            None  None     None   None
# 1          Date  Calories In     None            None  None     None   None
# 2    2018-09-27            0     None            None  None     None   None
# 3    2018-09-28            0     None            None  None     None   None
# 4    2018-09-29            0     None            None  None     None   None
# ..          ...          ...      ...             ...   ...      ...    ...
# 345         NaN        Fiber      0 g            None  None     None   None
# 346         NaN        Carbs      0 g            None  None     None   None
# 347         NaN       Sodium     0 mg            None  None     None   None
# 348         NaN      Protein      0 g            None  None     None   None
# 349         NaN        Water  0 fl oz            None  None     None   None
#
# ...
